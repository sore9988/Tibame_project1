# %%
import pandas as pd
train_df = pd.read_csv("中山區燒烤/中山區燒烤/train_all.csv", encoding="utf-8")
train_df
# Out:
#        id   date  star                                               text  \
# 0       0  1 個月前     5                                                 ""
# 1       1  2 個月前     5                           "海鮮新鮮，烹調美味，地方也真的很居酒屋，讚！"
# 2       2  5 個月前     1                      "蝦子非常不新鮮，蝦子也很小，9隻550覺得太誇張..."
# 3       3  6 個月前     5                                                 ""
# 4       4  7 個月前     1  "很不推的一間!!，超難吃的雞肉串! 明太子雞串 根本就是去頂好買雞肉丁 直接串 完全沒味道...
# ...   ...    ...   ...                                                ...
# 3737  697   1 年前     5                                                 ""
# 3738  698   1 年前     5                                     " 值得@ 1000％，，"
# 3739  699   1 年前     3                                                 ""
# 3740  700   1 年前     4                                                 ""
# 3741  701   1 年前     3                          "口味，環境，服務，氣氛都比較適合年輕族群聚會。"
#
#                                 dem
# 0                           中天活蝦居酒屋
# 1                           中天活蝦居酒屋
# 2                           中天活蝦居酒屋
# 3                           中天活蝦居酒屋
# 4                           中天活蝦居酒屋
# ...                             ...
# 3737  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)
# 3738  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)
# 3739  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)
# 3740  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)
# 3741  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)
#
# [3742 rows x 5 columns]

# %%
train_dem_list = train_df["dem"].unique()
train_dem_list
# Out:
# array(['中天活蝦居酒屋', '享坐海鮮直烤', '京東燒肉專門店', '台灣夯BAR串燒烤小店', '呷食益(Just Eat南京店)',
#        '小天海鮮燒烤', '柒 串燒屋', '穗.居酒屋', '蟹宴日式頂級帝王蟹燒烤鍋物', '遇見燒烤',
#        '頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)'], dtype=object)

# %%
# train_df[train_df["dem"] == "柒 串燒屋"]

# %%
train_dd = train_df[["dem",  "star", "date", "text"]]
# 抓出不到一個月的 index => 改時間
date_2 = []
for l in train_dd["date"]:
    date_2.append("年" in l)
date2_index = train_dd[date_2].index
for dd in date2_index:
    train_dd.loc[dd,'date'] = '13 個月以上'
date_1 = []
for l in train_dd["date"]:
    date_1.append("天" in l)
date1_index = train_dd[date_1].index
for d in date1_index:
    train_dd.loc[d,'date'] = '1 個月內'
date_3 = []
for l in train_dd["date"]:
    date_3.append("小時" in l)
date3_index = train_dd[date_3].index
for d in date3_index:
    train_dd.loc[d,'date'] = '1 個月內'
train_dd.to_csv("中山區燒烤/中山區燒烤/train_dd_all.csv", encoding="utf-8", index=False)
train_dd
# Out:
# C:\Users\sore\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                                 dem  star     date  \
# 0                           中天活蝦居酒屋     5    1 個月前
# 1                           中天活蝦居酒屋     5    2 個月前
# 2                           中天活蝦居酒屋     1    5 個月前
# 3                           中天活蝦居酒屋     5    6 個月前
# 4                           中天活蝦居酒屋     1    7 個月前
# ...                             ...   ...      ...
# 3737  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)     5  13 個月以上
# 3738  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)     5  13 個月以上
# 3739  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)     3  13 個月以上
# 3740  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)     4  13 個月以上
# 3741  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)     3  13 個月以上
#
#                                                    text
# 0                                                    ""
# 1                              "海鮮新鮮，烹調美味，地方也真的很居酒屋，讚！"
# 2                         "蝦子非常不新鮮，蝦子也很小，9隻550覺得太誇張..."
# 3                                                    ""
# 4     "很不推的一間!!，超難吃的雞肉串! 明太子雞串 根本就是去頂好買雞肉丁 直接串 完全沒味道...
# ...                                                 ...
# 3737                                                 ""
# 3738                                     " 值得@ 1000％，，"
# 3739                                                 ""
# 3740                                                 ""
# 3741                          "口味，環境，服務，氣氛都比較適合年輕族群聚會。"
#
# [3742 rows x 4 columns]

# %%
# 依日期分
date_2_oo = [] # 一年前
date_2_o = [] # 半年前
date_2_n = [] # 半年內
for i in train_dd["date"]:
    date_2_oo.append(int(i[0:2]) >= 13)
    date_2_o.append(int(i[0:2]) > 6 and int(i[0:2]) <= 12)
    date_2_n.append(int(i[0:2]) <= 6)
train_oo = train_dd[date_2_oo]
train_o = train_dd[date_2_o]
train_n = train_dd[date_2_n]
train_oo
# Out:
#                                 dem  star     date  \
# 11                          中天活蝦居酒屋     1  13 個月以上
# 12                          中天活蝦居酒屋     5  13 個月以上
# 13                          中天活蝦居酒屋     2  13 個月以上
# 14                          中天活蝦居酒屋     1  13 個月以上
# 15                          中天活蝦居酒屋     1  13 個月以上
# ...                             ...   ...      ...
# 3737  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)     5  13 個月以上
# 3738  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)     5  13 個月以上
# 3739  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)     3  13 個月以上
# 3740  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)     4  13 個月以上
# 3741  頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)     3  13 個月以上
#
#                                                    text
# 11    "我真的無言 外送500多 兩份水晶魚一份鯰魚塊 加起來可以裝不到半盒高度的長方形便當盒 你...
# 12                                                   ""
# 13                                                   ""
# 14    "可以請你們半夜閉嘴嗎 附近鄰居都不用睡覺? ，要聊天到店裡面聊可以嗎 你們在外面聊天的聲音...
# 15         "使用foodpanda外送，蝦子腥到無法入口，是新鮮度的問題而非外送導致料理冷熱問題"
# ...                                                 ...
# 3737                                                 ""
# 3738                                     " 值得@ 1000％，，"
# 3739                                                 ""
# 3740                                                 ""
# 3741                          "口味，環境，服務，氣氛都比較適合年輕族群聚會。"
#
# [1766 rows x 4 columns]

# %%
trans = {v:k for k, v in enumerate(train_df["dem"].unique())}
reverse_trans = {k:v for k, v in enumerate(train_df["dem"].unique())}
trans
# Out:
# {'中天活蝦居酒屋': 0,
#  '享坐海鮮直烤': 1,
#  '京東燒肉專門店': 2,
#  '台灣夯BAR串燒烤小店': 3,
#  '呷食益(Just Eat南京店)': 4,
#  '小天海鮮燒烤': 5,
#  '柒 串燒屋': 6,
#  '穗.居酒屋': 7,
#  '蟹宴日式頂級帝王蟹燒烤鍋物': 8,
#  '遇見燒烤': 9,
#  '頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃)': 10}

# %%
y_train = train_df["dem"].replace(trans)
y_train
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 3737    10
# 3738    10
# 3739    10
# 3740    10
# 3741    10
# Name: dem, Length: 3742, dtype: int64

# %%
# apply重要 : data frame 的跟 series 的不同
def commendcut(s):
    s = " ".join(jieba.cut(s))
    s = s.replace("\r"," ").replace("\n"," ").replace('\" \"', "")
    return s
train = train_df["text"].apply(commendcut)  # 不要加 ()

# %%
train
# Out:
# 0
# 1                 " 海鮮 新鮮 ， 烹調 美味 ， 地方 也 真的 很居酒 屋 ， 讚 ！ "
# 2          " 蝦子 非常 不 新鮮 ， 蝦子 也 很小 ， 9 隻 550 覺得 太 誇張 ... "
# 3
# 4       " 很 不 推 的 一間 ! ! ， 超 難吃 的 雞肉 串 !   明太子 雞串   根本...
#                               ...
# 3737
# 3738                              "   值得 @   1000 ％ ， ， "
# 3739
# 3740
# 3741             " 口味 ， 環境 ， 服務 ， 氣氛 都 比較 適合 年輕 族群 聚會 。 "
# Name: text, Length: 3742, dtype: object

# %%
# 全部店家的關鍵字查詢
from jieba.analyse import extract_tags
train_g = ""
for i in train:
    train_g = train_g + i
catch_list = extract_tags(train_g, topK=2000)
s = ""
for i in train:
    s = s + " " + i
s = s.replace("評論 Google 翻譯", "")
fp = open("catch.txt", "w", encoding="utf-8")
fp.write(s)
fp.close()

# %%
with open("catch.txt", "r", encoding="utf-8") as f:
    mytext = f.read()

# %%
# for j in range(len(train_dem_list)):
train_oo_d = []
train_o_d = []
train_n_d = []
for i in train_dem_list:
    train_oo_d.append(train_oo[train_oo["dem"] == i]["text"].apply(commendcut))
    train_o_d.append(train_o[train_o["dem"] == i]["text"].apply(commendcut))
    train_n_d.append(train_n[train_n["dem"] == i]["text"].apply(commendcut))
train_o_d
# Out:
# [4     " 很 不 推 的 一間 ! ! ， 超 難吃 的 雞肉 串 !   明太子 雞串   根本...
#  5                               " 活蝦 料理 和 烤物 隨便 點都 好吃 "
#  6                                " 我 女朋友 喜歡 這邊 的 胡椒 蝦 "
#  7
#  8
#  9
#  10
#  Name: text, dtype: object,
#  67
#  68
#  69     " 特別 推薦 台北 建國北路 ， 民生東路 口 ， 澎湖 海鮮 直送 。 新鮮 的 生 蠔...
#  70     " 牛排 王 難得 的 休假 ， 來 試試看 這間 ， 還 真不錯 ， 烤 蠔 1 盤才 1...
#  71     " 海鮮 新鮮 ， ㄧ 進門 就 可以 看到 超大 蒸籠 料理 裝飾 很 氣派 ， 每道 料...
#                               ...
#  124    " 201905 ， 海鮮 的 條件 直送 厲害 ， 是 真的 新鮮 ， 可惜 這次 來 吃...
#  125
#  126                                        " 好吃 ！ 新鮮 ！ "
#  127
#  128
#  Name: text, Length: 62, dtype: object,
#  311                          " 限量 的 一頭 牛 套餐 好吃 ， 但 吃不飽 "
#  312              " 可惜 沒 體驗 到代烤   但 食材 相當 優秀   服務 也 很 好 "
#  313    " 肉 好吃 ， 服務 不錯 ， 頭 一次 吃 燒烤 還蠻 讓 人 舒服 自在 也 不會 太趕 "
#  314    " 桌邊 服務 燒烤 很 用心   日本 A5 的 和 牛 油脂 豐富   值得   推薦 ...
#  315
#                               ...
#  394
#  395
#  396                                 "   和 厚切 牛舌 喇舌 ， ， "
#  397    " 價格 偏高 ， 我們 一群 女生 都點 一頭 牛 ， 也 就 8 、 9 分飽 ， 男生...
#  398    " 非常 令人滿意 ， 強烈 的 爐火 可以 讓 肉汁 輕易 的 被 鎖住 ， 並且 容易 ...
#  Name: text, Length: 88, dtype: object,
#  606
#  607
#  Name: text, dtype: object,
#  1022                                           " 位子 較 小 "
#  1023                                         " 椒鹽 香菇 好吃 "
#  1024                          " 肉還 不錯 ， 裝潢 偏舊 。 價錢 親切 ！ "
#  1025                                        " 每 一間 都 好吃 "
#  1026    " 食材 沒 問題 ， 服務態度 跟 店家 態度 有 很大 的 問題 ， ， 因 下班時間 ...
#                                ...
#  1411
#  1412                    " 擁有 豐富 的 肉品 種類 ， 冰淇淋 也 不 遑 多 讓 "
#  1413                                    "   肉肉 都 好吃 ， ， "
#  1414                          "   牛肉 好 ㄘ ， 冰淇淋 也好 ㄘ ， ， "
#  1415
#  Name: text, Length: 394, dtype: object,
#  2005
#  2006    " 小天 是 一個 很 隨和 的 店家 ， 東西 非常 新鮮 好吃 ， 只要 你 是 老 饕...
#  2007                        " 不怎麼樣 的 好吃   老闆 很 用心 哦 ！ ！ "
#  Name: text, dtype: object,
#  2215
#  2216
#  2217
#  2218        " 平價 串燒 ， 適合 宵夜 小酌 ， 店家 服務 很 周到 ， 態度 也 很棒 ！ "
#  2219    " 串燒 都 蠻 好吃 ， 尤其 是 蔬菜類 的 很 喜歡 。 環境 很棒 ， 服務 很 好...
#                                ...
#  2395    " 回訪 數次   內用 座位 比較 擠   外帶 串燒 味道 還是 很 好 ， 很 好吃 ...
#  2396
#  2397
#  2398             " 好吃 服務 人員 態度 很 好 ! ! ， 軟絲超 好吃 的 ~ ~ 😋 "
#  2399
#  Name: text, Length: 185, dtype: object,
#  2731                       " 隔壁 酒客 都 很帥 ， 東西 好吃   價格 實惠 "
#  2732                                          " 食物 還 可以 "
#  2733
#  2734
#  2735
#  2736    "   這是 一家 合理 的 日式 酒吧 。 ， 旋鈕 也 很 好吃 。 ， 商店 裡的 狗...
#  2737
#  2738
#  2739                                       " 室內 會 有人 抽菸 "
#  2740
#  2741                         " 好吃 ～ 酒類 有 韓國 燒酒 可 選擇 ！ ！ "
#  2742
#  2743                                        " 老闆 帥 的 出水 "
#  2744
#  2745
#  Name: text, dtype: object,
#  2856                                   " 燒烤 吃 到 飽 啤酒 免費 "
#  2857    " 這裡 可以 烤 A5 和 牛 、 帝王 蟹 、 龍蝦 超 讚 啦 。 生魚片 、 手 捲...
#  2858                                           " 不錯 吃 。 "
#  2859    " 當天 飲料 只有 冰箱 櫃 的 鋁箔 包 飲料 ， 備料 也 不齊 ， 上菜 也 漏單 ...
#  2860
#  2861
#  2862
#  2863
#  2864            " 現場 服務 人員 服務 不錯 ， 給 個 讚 ！ ， 食材 部分 就 普普 "
#  2865
#  2866
#  2867                           " 食材 新鮮 ， 服務 優質 ， 直 得 推薦 "
#  2868    " 帝王 蟹 真真切切 吃 到 飽 ， 烤 的 超 好吃 ！ 服務員 球球 烤功 一流 ， ...
#  2869                                  "   球球 都 很棒 ！ ， ， "
#  2870    " 食材 都 不錯 ， 生 蠔 和 帝王 蟹 ( 生蟹 ) 太 優秀 了 ， 吃 的 到 甘...
#  2871                      " 整體 用餐 很 舒服 ， 東西 很 肥嫩 吃 很飽 9 "
#  2872
#  2873
#  2874
#  2875
#  2876    " 本來 以為 帝王 蟹 可以 吃 到 飽 ， 原來 套餐 包括 前菜 刺身 燒肉 等等 ，...
#  2877                                         "   不錯 ， ， "
#  2878    " 和 網上 之 相片 ,   有 少許 差異 .   皇帝 蟹 偏 小 ,   有 點點 ...
#  2879
#  2880    " 說 一定 要 7 : 30 到 因為 會 客滿 ， 結果 去 了連 一個 都 沒有 ， ...
#  2881
#  2882                                         " 服務 人員 親切 "
#  2883
#  2884
#  2885                                   " 帝王 蟹 吃 到 飽 ， 讚 "
#  2886
#  2887
#  2888                 " 很 好吃   很 新鮮   服務 很 好   環境 也 很 乾淨 "
#  2889    " 說 吃 到 飽 是 好聽 的 ， 火鍋 煮 了 20 分鐘 還沒滾 ， 幫 你 烤 不用...
#  2890      " 食材 新鮮 高級 多樣 ， 服務 親切 周到 ， 讓 人 想 再次 光臨 的 好 餐廳 "
#  2891
#  2892    " 用餐 2 小時 ， 只有 一個 服務 人員 在 幫 烤 三組 客人 ， 可以 理解 客人...
#  2893    " 女 服務生 態度惡劣 ， 食材 平平 ， 1500 元 等級 來說 ， 水準 太差 ， ...
#  2894    " 食材 不錯 ， 但 烤生 蠔有 些許 不 新鮮 ( 臭掉 了 ) 。   服務 很 好 ...
#  2895    " 服務態度 还 oK ， 但是 蚵 仔 ， 蛤仔 不 新鲜 有 嗅味 ， 送活 龍蝦 很棒...
#  2896    " 服務態度 極差 ， 中午 一點 過去 整間 店 都 沒人 ， 跟 我講 沒 位子 是 怎...
#  2897    " 食物 不錯 吃 ， 會 幫忙 烤 也 不錯 ， 但 最大 的 缺點 是 服務 人員 會 ...
#  Name: text, dtype: object,
#  Series([], Name: text, dtype: object),
#  3244                       " 難烤 要死 ， 不好吃 … … 沒想 再 去 … … "
#  3245
#  3246
#  3247    " 第一次 吃   我給 五顆星   ， 可能 因為 人少   好吃   服務 好   設備...
#  3248                                     "   出菜 速度慢 ， ， "
#                                ...
#  3374
#  3375
#  3376    " 以前 一直 覺得 頂燒 的 服務態度 超差 ， 還要 收 10% 服務費 ， 不過 今天...
#  3377
#  3378
#  Name: text, Length: 135, dtype: object]

# %%
for i in train_dem_list:
    train_m_oo = train_oo[train_oo["dem"] == i]["text"]
    s = ""
    for j in train_m_oo:
        s = s + " " + j
    fp = open("中山區燒烤/中山區燒烤/text/" + i + "_oo.txt", "w", encoding="utf-8")
    fp.write(s)
    fp.close()
    
    train_m_o = train_o[train_o["dem"] == i]["text"]
    s = ""
    for j in train_m_o:
        s = s + " " + j
    fp = open("中山區燒烤/中山區燒烤/text/" + i + "_o.txt", "w", encoding="utf-8")
    fp.write(s)
    fp.close()
    
    train_m_n = train_n[train_n["dem"] == i]["text"]
    s = ""
    for j in train_m_n:
        s = s + " " + j
    fp = open("中山區燒烤/中山區燒烤/text/" + i + "_n.txt", "w", encoding="utf-8")
    fp.write(s)
    fp.close()

# %%
# 大於一年個別店家的關鍵字抓取查詢
from jieba.analyse import extract_tags
for l in range(len(train_oo_d)):
    train_g = ""
    for i in train_oo_d[l]:
        train_g = train_g + i
    catch_list_oo = extract_tags(train_g, topK=200)
    s = ""
    for j in catch_list_oo:
        s = s + " " + j
    fp = open("中山區燒烤/中山區燒烤/catch/" + train_dem_list[l] + "_oo.txt", "w", encoding="utf-8")
    fp.write(s)
    fp.close()

# %%
for l in range(len(train_o_d)):
    train_g = ""
    for i in train_o_d[l]:
        train_g = train_g + i
    catch_list_o = extract_tags(train_g, topK=200)
    s = ""
    for j in catch_list_o:
        s = s + " " + j
    fp = open("中山區燒烤/中山區燒烤/catch/" + train_dem_list[l] + "_o.txt", "w", encoding="utf-8")
    fp.write(s)
    fp.close()

# %%
for l in range(len(train_n_d)):
    train_g = ""
    for i in train_n_d[l]:
        train_g = train_g + i
    catch_list_n = extract_tags(train_g, topK=200)
    s = ""
    for j in catch_list_n:
        s = s + " " + j
    fp = open("中山區燒烤/中山區燒烤/catch/" + train_dem_list[l] + "_n.txt", "w", encoding="utf-8")
    fp.write(s)
    fp.close()

# %%
## 個別店家的三種時間的文字雲
# from wordcloud import WordCloud
# import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline
# text_list = ["_oo.txt", "_o.txt", "_n.txt"]
# text_list_tan = []
# for i in range(len(train_dem_list)):
#     text_list_tan = text_list_tan + ["_oo.txt", "_o.txt", "_n.txt"]
# # for i in range(len(train_dem_list)*3):
# #     j = str(int(len(train_dem_list)/2)) + "6" + str(i+1)
# #     sub_list.append(int(j))
# # sub_list
# x = 0
# plt.figure(figsize=(50, 70))
# weight = 90
# height = 70
# plt.axis("off")
# plt.subplots(3, 11)
# for i in train_dem_list:
#     for t in range(len(text_list)):
#         with open("中山區燒烤/中山區燒烤/text/" + i + text_list[t], "r", encoding="utf-8") as f:
#             mytext = f.read()
#         wordcloud = WordCloud(font_path="simsun.ttf").generate(mytext)
#         plt.title(text_list[t] + i)
#         plt.plot(wordcloud, interpolation='bilinear')
#         x = x+1

# %%
# 全部評論的文字雲
from wordcloud import WordCloud
wordcloud = WordCloud(font_path="simsun.ttf").generate(mytext)
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer()
x_train = vec.fit_transform(train)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(x_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# 輸入關鍵字查詢合適的店家
s = input("輸入關鍵字")
s = vec.transform([commendcut(s)])
pre = clf.predict(s)[0]
print(pre)
ans = reverse_trans[pre]
print("應該吃:", ans)
proba = clf.predict_proba(s)[0]
proba = list(enumerate(proba))
for i, prob in sorted(proba, key=lambda x:x[1], reverse=True):
    print(reverse_trans[i], ":", prob * 100, "%")
# Out:
# 輸入關鍵字態度惡劣
# 4
# 應該吃: 呷食益(Just Eat南京店)
# 呷食益(Just Eat南京店) : 23.05161582727987 %
# 頂燒-吃到飽火鍋 頂級燒烤肉 公司家庭聚會(推薦人氣必吃) : 20.391719379527945 %
# 柒 串燒屋 : 18.011419287913107 %
# 蟹宴日式頂級帝王蟹燒烤鍋物 : 15.0510096899935 %
# 京東燒肉專門店 : 10.03628274069152 %
# 享坐海鮮直烤 : 7.759366445936709 %
# 穗.居酒屋 : 3.0873723144131078 %
# 中天活蝦居酒屋 : 1.2490429316662544 %
# 台灣夯BAR串燒烤小店 : 0.6158206100764455 %
# 小天海鮮燒烤 : 0.6037292645053488 %
# 遇見燒烤 : 0.14262150799612025 %
